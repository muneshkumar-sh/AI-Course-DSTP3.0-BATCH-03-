# %%
def greet():
    print("Welcome to python course!")

greet()
# Out:
# Welcome to python course!

# %%
def greet(name):
    print("Welcome ", name)

greet("Munesh")
# Out:
# Welcome  Munesh

# %%
def add(a,b):
    return a+b

result= add(3,10)
print(result)
# Out:
# 13

# %%
def square(numb):
    return numb*numb

result=square(10)
print(result)
print(square(12))
# Out:
# 100
# 144

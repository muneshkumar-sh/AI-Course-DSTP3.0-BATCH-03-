# %%
age="34"
print(age)
type(age)
# Out:
# 34
# str

# %%
print(int(age)+1)
# Out:
# 35

# %%
# input fron user
input("Enter your age: ")
# Out:
# Enter your age:  22
# '22'

# %%
# input fron user
name=input("Enter your name: ")
# Out:
# Enter your name:  Munesh Kumar

# %%
print(name)
# Out:
# Munesh Kumar

# %%
# input fron user
my_age=input("Enter your age: ")
type(my_age)
# Out:
# Enter your age:  22
# str

# %%
print(type(my_age))
# Out:
# <class 'str'>

# %%
my_age=int(my_age)
type(my_age)
# Out:
# int

# %%
age=23

# %%
print(age)
# Out:
# 23

# %%
score=3.5

# %%
print(score)
# Out:
# 3.5

# %%
type(score)
# Out:
# float

# %%
type(age)
# Out:
# int

# %%
print(score+1)
# Out:
# 4.5

# %%
print(age+1)
# Out:
# 24

# %%
age=21

# %%
print(age)
# Out:
# 21

# %%
name="Munesh Kumar"

# %%
print(name)
# Out:
# Munesh Kumar

# %%
print(name+" Suthar")
# Out:
# Munesh Kumar Suthar

# %%
surname=" Suthar"
name+=surname
print(name)
# Out:
# Munesh Kumar Suthar

# %%
isPassed=True
print(isPassed)
# Out:
# True

# %%
isPassed=fals

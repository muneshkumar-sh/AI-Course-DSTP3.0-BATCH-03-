# %%
class Student:
    def __init__(self, name, grade):
        self.__grade=grade  # here __ shows that grade is private attribute

student1=Student("Ali", 90)
print(student1.__grade) # shows error, we can't access private attribute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 6
#       3         self.__grade=grade  # here __ shows that grade is private attribute
#       5 student1=Student("Ali", 90)
# ----> 6 print(student1.__grade) # shows error, we can't access private attribute
#
# AttributeError: 'Student' object has no attribute '__grade'

# %%
class Student:
    def __init__(self, name, grade):
        self.__grade=grade  # here __ shows that grade is private attribute

    def get_grade(self): # access private attribute by creating method
        return self.__grade
        
student1=Student("Ali", 90)
print(student1.get_grade())
# Out:
# 90

# %%
class Student:
    @property
    def grade(self):
        return self.__grade
        
    def __init__(self, name, grade):
        self.__grade=grade  # here __ shows that grade is private attribute
        
    def get_grade(self): # access private attribute by creating method
        return self.__grade
        
    def set_grade(self, grade):
        if 0<=grade<=100:
            self.__grade=grade
        else:
            print("Invalid Value")
        
student1=Student("Ali", 90)
student1.set_grade(95)
print(student1.get_grade())
# Out:
# 95

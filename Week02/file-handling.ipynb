# %%
file=open('demo.txt', 'r')

# %%
print(file.read())
# Out:
# This is another object2

# %%
file.close()

# %%
file=open('demo.txt', 'w')

# %%
file.write("This is another object")
# Out:
# 22

# %%
file.close()

# %%
file=open('demo.txt', 'a') # append means add text without overrinding previous text
file.write("\nThis is another object2")
# Out:
# 24

# %%
file.close()

# %%
num=int(input("Enter Number: "))
print(10/num)
# Out:
# Enter Number:  5
# 2.0

# %%
# if invalid user input
try:
    num=int(input("Enter Number: "))
    print(10/num)
except ZeroDivisionError:
    print("You can not divide by zero")
except ValueError:
    print("That's not a number")
except Exception as e:
    print(f"an unexcepted error occured: {e}")
# Out:
# Enter Number:  10
# 1.0

# %%
try:
    print("Running Code")
except:         # handle all possible error
    print("Error found")
else:
    print("No Error found")
finally:
    print("Done")
# Out:
# Running Code
# No Error found
# Done

# %%
# we can raise error

age = -1

# %%
if age<0:
    raise ValueError("Age can not be negative")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 if age<0:
# ----> 2     raise ValueError("Age can not be negative")
#
# ValueError: Age can not be negative

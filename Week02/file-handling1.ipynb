# %%
with open("demo.txt", "r") as file: # with context manager
    data=file.read()
    print(data)
# close file automatically here
# Out:
# This is another object2This is another object2This is another object2/nThis is another object2
# This is another object2

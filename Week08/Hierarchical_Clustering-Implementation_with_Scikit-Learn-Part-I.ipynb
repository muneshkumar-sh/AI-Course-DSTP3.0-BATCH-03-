# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

# %%
data=load_iris()
x=pd.DataFrame(data.data, columns=data.feature_names)

print("Dataset shape: ", x.shape)
print("\nFirst 5 rows:\n", x.head())
# Out:
# Dataset shape:  (150, 4)
#
# First 5 rows:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# 2) Fit Hierarchical (Agglomerative) Clustering
hc = AgglomerativeClustering(
    n_clusters=3,      # number of clusters to extract
    linkage='ward'     # minimizes within-cluster variance
)

cluster_labels = hc.fit_predict(x)

# %%
# 3) Attach cluster labels to dataset
x["Cluster"] = cluster_labels

print("\nCluster counts:")
print(x["Cluster"].value_counts())
# Out:
# Cluster counts:
# Cluster
# 0    64
# 1    50
# 2    36
# Name: count, dtype: int64

# %%
print("\nSample with cluster labels:")
print(x.head())
# Out:
# Sample with cluster labels:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Cluster
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

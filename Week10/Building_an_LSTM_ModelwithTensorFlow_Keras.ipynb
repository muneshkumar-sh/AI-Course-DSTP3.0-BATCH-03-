# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import LSTM, Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Load the data
df_loaded = pd.read_csv('module_159_data.csv')

# Separate features and target
X = df_loaded.drop('target', axis=1).values
y = df_loaded['target'].values

# Reshape data for LSTM
# From (2000, 10) to (2000, 10, 1)
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
# Build the model
model = Sequential([
    LSTM(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

# Display model summary
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32)             │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385 (17.13 KB)
#  Trainable params: 4,385 (17.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the model
model.fit(
    X,
    y,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5031 - loss: 0.6789 - val_accuracy: 0.4325 - val_loss: 0.6838
# Epoch 2/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6731 - loss: 0.5627 - val_accuracy: 0.7775 - val_loss: 0.5015
# Epoch 3/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8012 - loss: 0.4356 - val_accuracy: 0.8075 - val_loss: 0.4093
# Epoch 4/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8363 - loss: 0.3810 - val_accuracy: 0.8300 - val_loss: 0.3931
# Epoch 5/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8575 - loss: 0.3281 - val_accuracy: 0.8275 - val_loss: 0.3355
# Epoch 6/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8788 - loss: 0.2882 - val_accuracy: 0.8350 - val_loss: 0.3334
# Epoch 7/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8800 - loss: 0.2711 - val_accuracy: 0.8500 - val_loss: 0.2996
# Epoch 8/20
# ...

# %%
# Evaluate the model and print only the accuracy
print(f"\nFinal Accuracy: {model.evaluate(X, y, verbose=0)[1]:.4f}")
# Out:
# Final Accuracy: 0.9455

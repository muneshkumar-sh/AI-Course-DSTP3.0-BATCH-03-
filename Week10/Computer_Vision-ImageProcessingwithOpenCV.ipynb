# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\munesh kumar\anaconda3\lib\site-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in c:\users\munesh kumar\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Basic Image Processing using OpenCV

# Topics covered:
# 1. Reading and displaying images
# 2. Image filtering
# 3. Edge detection
# 4. Image transformations

import cv2
import numpy as np

# --------------------------------------------------
# 1. Load Image
# --------------------------------------------------

image = cv2.imread("flower.jpg")

if image is None:
    print("Error: Image not found.")
    exit()

cv2.imshow("Original Image", image)
cv2.waitKey(0)

# --------------------------------------------------
# 2. Convert to Grayscale
# --------------------------------------------------

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow("Grayscale", gray)
cv2.waitKey(0)
# Out:
# 32

# %%
# --------------------------------------------------
# 3. Image Filtering (Noise Reduction)
# --------------------------------------------------

# Gaussian Blur
blur = cv2.GaussianBlur(gray, (5, 5), 0)

cv2.imshow("Gaussian Blur", blur)
cv2.waitKey(0)

# Median Filter
median = cv2.medianBlur(gray, 5)

cv2.imshow("Median Filter", median)
cv2.waitKey(0)
# Out:
# 32

# %%
# --------------------------------------------------
# 4. Edge Detection
# --------------------------------------------------

edges = cv2.Canny(gray, 100, 200)

cv2.imshow("Edge Detection (Canny)", edges)
cv2.waitKey(0)
# Out:
# 32

# %%
# --------------------------------------------------
# 5. Image Transformations
# --------------------------------------------------

# Resize
resized = cv2.resize(image, (400, 300))

cv2.imshow("Resized", resized)
cv2.waitKey(0)

# Rotation
height, width = image.shape[:2]
center = (width // 2, height // 2)

rotation_matrix = cv2.getRotationMatrix2D(center, 45, 1)

rotated = cv2.warpAffine(
    image,
    rotation_matrix,
    (width, height)
)

cv2.imshow("Rotated Image", rotated)
cv2.waitKey(0)

# Flip
flipped = cv2.flip(image, 1)

cv2.imshow("Flipped Image", flipped)
cv2.waitKey(0)
# Out:
# 32

# %%
# --------------------------------------------------
# 6. Save Processed Image
# --------------------------------------------------

cv2.imwrite("edges_output.jpg", edges)

cv2.destroyAllWindows()
